# %%
import pandas as pd

# %%
vgsales = pd.read_csv("/content/vgsales.csv")

# %%
vgsales.shape
# Out:
# (12819, 11)

# %%
vgsales.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
vgsales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgsales.head(n=6)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26

# %%
vgsales.tail()
# Out:
#         Rank                                             Name Platform  \
# 12814  12816    Jikkyou Powerful Pro Yakyuu DreamCast Edition       DC
# 12815  12817  Carmen Sandiego: The Secret of the Stolen Drums      PS2
# 12816  12818  Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan      PSP
# 12817  12819                         Activision Hits: Remixed      PSP
# 12818  12820                       Death Jr. II: Root of Evil      PSP
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 12814  2000.0        Sports  Konami Digital Entertainment      0.00      0.00
# 12815  2004.0        Action            BAM! Entertainment      0.03      0.02
# 12816  2010.0  Role-Playing                         Atlus      0.00      0.00
# 12817  2006.0          Misc                    Activision      0.05      0.00
# 12818  2006.0      Platform                     Konami Di       NaN       NaN
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
vgsales.tail(6)
# Out:
#         Rank                                             Name Platform  \
# 12813  12815                                         SeaBlade       XB
# 12814  12816    Jikkyou Powerful Pro Yakyuu DreamCast Edition       DC
# 12815  12817  Carmen Sandiego: The Secret of the Stolen Drums      PS2
# 12816  12818  Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan      PSP
# 12817  12819                         Activision Hits: Remixed      PSP
# 12818  12820                       Death Jr. II: Root of Evil      PSP
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 12813  2002.0       Shooter                TDK Mediactive      0.04      0.01
# 12814  2000.0        Sports  Konami Digital Entertainment      0.00      0.00
# 12815  2004.0        Action            BAM! Entertainment      0.03      0.02
# 12816  2010.0  Role-Playing                         Atlus      0.00      0.00
# 12817  2006.0          Misc                    Activision      0.05      0.00
# ...

# %%
vgsales.sample(5)
# Out:
#         Rank                                  Name Platform    Year  \
# 11834  11836                             Roll Away       PS  1998.0
# 9409    9411  Scene It? Bright Lights! Big Screen!      PS3  2009.0
# 7263    7265                    NCAA Basketball 09     X360  2008.0
# 9785    9787                            Cel Damage       XB  2001.0
# 6960    6962                           Love Plus +       DS  2010.0
#
#             Genre                               Publisher  NA_Sales  EU_Sales  \
# 11834      Puzzle             Sony Computer Entertainment      0.04      0.03
# 9409         Misc  Warner Bros. Interactive Entertainment      0.10      0.01
# 7263       Sports                         Electronic Arts      0.20      0.00
# 9785       Racing                         Electronic Arts      0.09      0.03
# 6960   Simulation            Konami Digital Entertainment      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 11834      0.00         0.00          0.07
# ...

# %%
vgsales.Name
# Out:
# 0                                             Wii Sports
# 1                                      Super Mario Bros.
# 2                                         Mario Kart Wii
# 3                                      Wii Sports Resort
# 4                               Pokemon Red/Pokemon Blue
#                               ...
# 12814      Jikkyou Powerful Pro Yakyuu DreamCast Edition
# 12815    Carmen Sandiego: The Secret of the Stolen Drums
# 12816    Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan
# 12817                           Activision Hits: Remixed
# 12818                         Death Jr. II: Root of Evil
# Name: Name, Length: 12819, dtype: object

# %%
vgsales['Name']
# Out:
# 0                                             Wii Sports
# 1                                      Super Mario Bros.
# 2                                         Mario Kart Wii
# 3                                      Wii Sports Resort
# 4                               Pokemon Red/Pokemon Blue
#                               ...
# 12814      Jikkyou Powerful Pro Yakyuu DreamCast Edition
# 12815    Carmen Sandiego: The Secret of the Stolen Drums
# 12816    Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan
# 12817                           Activision Hits: Remixed
# 12818                         Death Jr. II: Root of Evil
# Name: Name, Length: 12819, dtype: object

# %%
vgsales.iloc[0]
# Out:
# Rank                     1
# Name            Wii Sports
# Platform               Wii
# Year                2006.0
# Genre               Sports
# Publisher         Nintendo
# NA_Sales             41.49
# EU_Sales             29.02
# JP_Sales              3.77
# Other_Sales           8.46
# Global_Sales         82.74
# Name: 0, dtype: object

# %%
vgsales.iloc[0:4]
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 2     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85
# 3     4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo     15.75
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24
# 2     12.88      3.79         3.31         35.82
# 3     11.01      3.28         2.96         33.00

# %%
vgsales.iloc[0:5,0:5]
# Out:
#    Rank                      Name Platform    Year         Genre
# 0     1                Wii Sports      Wii  2006.0        Sports
# 1     2         Super Mario Bros.      NES  1985.0      Platform
# 2     3            Mario Kart Wii      Wii  2008.0        Racing
# 3     4         Wii Sports Resort      Wii  2009.0        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing

# %%
vgsales.iloc[:,[0,3,-2]]
# Out:
#         Rank    Year  Other_Sales
# 0          1  2006.0         8.46
# 1          2  1985.0         0.77
# 2          3  2008.0         3.31
# 3          4  2009.0         2.96
# 4          5  1996.0         1.00
# ...      ...     ...          ...
# 12814  12816  2000.0         0.00
# 12815  12817  2004.0         0.01
# 12816  12818  2010.0         0.00
# 12817  12819  2006.0         0.00
# 12818  12820  2006.0          NaN
#
# [12819 rows x 3 columns]

# %%
vgsales.loc[:,['Name','Genre']]
# Out:
#                                                   Name         Genre
# 0                                           Wii Sports        Sports
# 1                                    Super Mario Bros.      Platform
# 2                                       Mario Kart Wii        Racing
# 3                                    Wii Sports Resort        Sports
# 4                             Pokemon Red/Pokemon Blue  Role-Playing
# ...                                                ...           ...
# 12814    Jikkyou Powerful Pro Yakyuu DreamCast Edition        Sports
# 12815  Carmen Sandiego: The Secret of the Stolen Drums        Action
# 12816  Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan  Role-Playing
# 12817                         Activision Hits: Remixed          Misc
# 12818                       Death Jr. II: Root of Evil      Platform
#
# [12819 rows x 2 columns]

# %%
vgsales.loc[:,'Name']
# Out:
# 0                                             Wii Sports
# 1                                      Super Mario Bros.
# 2                                         Mario Kart Wii
# 3                                      Wii Sports Resort
# 4                               Pokemon Red/Pokemon Blue
#                               ...
# 12814      Jikkyou Powerful Pro Yakyuu DreamCast Edition
# 12815    Carmen Sandiego: The Secret of the Stolen Drums
# 12816    Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan
# 12817                           Activision Hits: Remixed
# 12818                         Death Jr. II: Root of Evil
# Name: Name, Length: 12819, dtype: object

# %%
vgsales.Genre =='Racing'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 12814    False
# 12815    False
# 12816    False
# 12817    False
# 12818    False
# Name: Genre, Length: 12819, dtype: bool

# %%
Racg =vgsales.loc[vgsales.Genre=='Racing']

# %%
Racg.head()
# Out:
#     Rank                    Name Platform    Year   Genre  \
# 2      3          Mario Kart Wii      Wii  2008.0  Racing
# 11    12           Mario Kart DS       DS  2005.0  Racing
# 28    29  Gran Turismo 3: A-Spec      PS2  2001.0  Racing
# 42    43            Mario Kart 7      3DS  2011.0  Racing
# 47    48          Gran Turismo 4      PS2  2004.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2                      Nintendo     15.85     12.88      3.79         3.31
# 11                     Nintendo      9.81      7.57      4.13         1.92
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 42                     Nintendo      4.74      3.91      2.67         0.89
# 47  Sony Computer Entertainment      3.01      0.01      1.10         7.53
#
#     Global_Sales
# 2          35.82
# 11         23.42
# 28         14.98
# 42         12.21
# 47         11.66

# %%
GracN = vgsales.loc[(vgsales.Genre=='Racing')
               &
        (vgsales.NA_Sales>=15)]

# %%
GracN
# Out:
#    Rank            Name Platform    Year   Genre Publisher  NA_Sales  \
# 2     3  Mario Kart Wii      Wii  2008.0  Racing  Nintendo     15.85
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2     12.88      3.79         3.31         35.82

# %%
vgsales.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
vgsales.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
vgsales.loc[vgsales.EU_Sales>25]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
vgsales.loc[vgsales.Name.str.contains('Mario',case=False,na=False)]
# Out:
#         Rank                                          Name Platform    Year  \
# 1          2                             Super Mario Bros.      NES  1985.0
# 2          3                                Mario Kart Wii      Wii  2008.0
# 6          7                         New Super Mario Bros.       DS  2006.0
# 8          9                     New Super Mario Bros. Wii      Wii  2009.0
# 11        12                                 Mario Kart DS       DS  2005.0
# ...      ...                                           ...      ...     ...
# 6588    6590   Mario & Sonic at the Rio 2016 Olympic Games     WiiU  2016.0
# 11282  11284                     Famicom Mini: Mario Bros.      GBA  2004.0
# 12123  12125                                  Mario Tennis      Wii  2010.0
# 12373  12375          Mario vs. Donkey Kong: Tipping Stars      3DS  2015.0
# 12770  12772  Dance Dance Revolution: Mario Mix (JP sales)       GC  2005.0
#
# ...

# %%
vgsales.loc[vgsales.Name.str.contains('Mario',case=True,na=False)]
# Out:
#         Rank                                          Name Platform    Year  \
# 1          2                             Super Mario Bros.      NES  1985.0
# 2          3                                Mario Kart Wii      Wii  2008.0
# 6          7                         New Super Mario Bros.       DS  2006.0
# 8          9                     New Super Mario Bros. Wii      Wii  2009.0
# 11        12                                 Mario Kart DS       DS  2005.0
# ...      ...                                           ...      ...     ...
# 6588    6590   Mario & Sonic at the Rio 2016 Olympic Games     WiiU  2016.0
# 11282  11284                     Famicom Mini: Mario Bros.      GBA  2004.0
# 12123  12125                                  Mario Tennis      Wii  2010.0
# 12373  12375          Mario vs. Donkey Kong: Tipping Stars      3DS  2015.0
# 12770  12772  Dance Dance Revolution: Mario Mix (JP sales)       GC  2005.0
#
# ...

# %%
print(vgsales.shape)
Vgn = vgsales.dropna(subset =['NA_Sales'])
print(Vgn.shape)
# Out:
# (12819, 11)
# (12818, 11)

# %%
vgsales.NA_Sales.map(lambda x:x+5)
# Out:
# 0        46.49
# 1        34.08
# 2        20.85
# 3        20.75
# 4        16.27
#          ...
# 12814     5.00
# 12815     5.03
# 12816     5.00
# 12817     5.05
# 12818      NaN
# Name: NA_Sales, Length: 12819, dtype: float64

# %%
def sub5(row):
   row.NA_Sales-=5
   return row
vgsales.apply(sub5,axis=1)
# Out:
#         Rank                                             Name Platform  \
# 0          1                                       Wii Sports      Wii
# 1          2                                Super Mario Bros.      NES
# 2          3                                   Mario Kart Wii      Wii
# 3          4                                Wii Sports Resort      Wii
# 4          5                         Pokemon Red/Pokemon Blue       GB
# ...      ...                                              ...      ...
# 12814  12816    Jikkyou Powerful Pro Yakyuu DreamCast Edition       DC
# 12815  12817  Carmen Sandiego: The Secret of the Stolen Drums      PS2
# 12816  12818  Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan      PSP
# 12817  12819                         Activision Hits: Remixed      PSP
# 12818  12820                       Death Jr. II: Root of Evil      PSP
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
vgsales.groupby('Genre').Genre.count()
# Out:
# Genre
# Action          2652
# Adventure        647
# Fighting         710
# Misc            1349
# Platform         752
# Puzzle           394
# Racing           995
# Role-Playing    1175
# Shooter         1063
# Simulation       649
# Sports          1992
# Strategy         441
# Name: Genre, dtype: int64

# %%
vgsales.groupby('EU_Sales').Name.count()
# Out:
# EU_Sales
# 0.00     3396
# 0.01      694
# 0.02      892
# 0.03      775
# 0.04      653
#          ...
# 9.27        1
# 11.00       1
# 11.01       1
# 12.88       1
# 29.02       1
# Name: Name, Length: 305, dtype: int64

# %%
Vg = vgsales.groupby('Genre').Genre.count()

# %%
Vg.sort_values(ascending=False)
# Out:
# Genre
# Action          2652
# Sports          1992
# Misc            1349
# Role-Playing    1175
# Shooter         1063
# Racing           995
# Platform         752
# Fighting         710
# Simulation       649
# Adventure        647
# Strategy         441
# Puzzle           394
# Name: Genre, dtype: int64

# %%
Vg.sort_values(ascending=True)
# Out:
# Genre
# Puzzle           394
# Strategy         441
# Adventure        647
# Simulation       649
# Fighting         710
# Platform         752
# Racing           995
# Shooter         1063
# Role-Playing    1175
# Misc            1349
# Sports          1992
# Action          2652
# Name: Genre, dtype: int64

# %%
vgsales.to_excel('Vg.xlsx')
